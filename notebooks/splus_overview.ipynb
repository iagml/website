# %% [markdown]
# ## Importando conjunto de dados da núvem

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# %ls
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive
# 'My Drive'/

# %% [markdown]
# ## Lendo conjunto de dados

# %%
import pandas as pd

path = '/gdrive/My Drive/ml_datasets/splus_march2019.cat.gz'

data = pd.read_csv(path, comment='#', delim_whitespace=True, compression='gzip', error_bad_lines=False)
data.describe()
# Out:
#                  RA           Dec  ...      PROB_GAL     PROB_STAR
# count  3.009731e+06  3.009731e+06  ...  3.009731e+06  3.009731e+06
# mean   2.393182e+02  3.729784e-02  ...  3.494156e-01  6.473472e-01
# std    1.293513e+02  8.079389e-01  ...  4.383151e-01  4.394139e-01
# min    0.000000e+00 -1.413900e+00  ...  0.000000e+00  0.000000e+00
# 25%    5.491730e+01 -6.595000e-01  ...  0.000000e+00  7.000000e-02
# 50%    3.058972e+02  4.090000e-02  ...  1.000000e-02  9.900000e-01
# 75%    3.205500e+02  7.371000e-01  ...  9.230000e-01  1.000000e+00
# max    3.600000e+02  1.450300e+00  ...  1.000000e+00  1.000000e+00
#
# [8 rows x 137 columns]

# %% [markdown]
# ## Histogramas

# %%
columns = ['r_petro', 'MUMAX', 'FWHM_n', 'A', 'zb', 'PROB_GAL']

for i in range(len(columns)):
  pd.DataFrame.hist(data=data, column=columns[i], bins=200, figsize=(7, 5))

# %% [markdown]
# ## Plots

# %%
import matplotlib.pyplot as plt


plt.ylim(0, 26)
plt.xlim(0, 28)
plt.ylabel('MUMAX')
plt.xlabel('r_petro')
plt.title('r_petro x MUMAX')
plt.scatter(data['r_petro'], data['MUMAX'])
plt.show()

# %%
plt.ylim(-50, 500)
plt.xlim(0, 35)
plt.ylabel('FWHM_n')
plt.xlabel('r_petro')
plt.title('r_petro x FWHM_n')
plt.scatter('r_petro', 'FWHM_n', data=data)
plt.show()
